# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
import csv

# %%
# get data from file

read_URL = "/Users/kailashanand/Documents/Developer/MC_OASIS/Task_Week4/loss_history_0.csv"

loss_values_string = []

with open(read_URL, 'r') as loss_data:
    csv_reader = csv.reader(loss_data)
    for row in csv_reader:
        loss_values_string = row
        break

loss_values_string.pop()
loss_values = np.array(loss_values_string, dtype=float)

plt.plot(loss_values[:1000:50])
